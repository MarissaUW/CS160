# %% [markdown]
# ## Web scraping from this site: https://www.washington.edu/students/crscat/

# %% [markdown]
# > import libraries and access site with requests library

# %%
import requests
import urllib.request
import time
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://www.washington.edu/students/crscat/'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup.findAll('a')[0].get_text()
# Out:
# 'Home'

# %%
download_url = 'https://www.washington.edu/students/crscat/'
urllib.request.urlretrieve(download_url)
time.sleep(1)
# Out:
# ('/var/folders/lx/w86_kbl15zz641zxm7gj5yjc0000gn/T/tmpbzquczd5',
#  <http.client.HTTPMessage at 0x112db25f8>)

# %%
df_UW = pd.read_csv('cat1.csv', index_col = 0, sep = ',')
df_UW = df_UW.fillna(0)
df_UW = df_UW.reset_index()
df_UW[['Course', 'Abbr']]= df_UW.Course.str.split('\(|\)', expand=True).iloc[:,[0,1]]
df_UW
# Out:
#                            School                              Department  \
# 0    College of Arts and Sciences                 American Ethnic Studies
# 1    College of Arts and Sciences                 American Ethnic Studies
# 2    College of Arts and Sciences                 American Ethnic Studies
# 3    College of Arts and Sciences                 American Ethnic Studies
# 4    College of Arts and Sciences                 American Ethnic Studies
# 5    College of Arts and Sciences                 American Ethnic Studies
# 6    College of Arts and Sciences                 American Ethnic Studies
# 7    College of Arts and Sciences                            Anthropology
# 8    College of Arts and Sciences                            Anthropology
# 9    College of Arts and Sciences                                       0
# 10   College of Arts and Sciences                     Applied Mathematics
# 11   College of Arts and Sciences                     Applied Mathematics
# ...
